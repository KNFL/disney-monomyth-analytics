# %% [markdown]
# # 01 - Intro EDA
# Objective: Prepare the initial dataset for the Disney Monomyth Analytics project.
# Date: 2026-03-08
# Notes: Create a reproducible pipeline after validating the dataset.

# %%
import os
import pandas as pd
import numpy as np
print("OK - imports loaded")
# Out:
# OK - imports loaded

# %%
# placeholder: usar data_raw/ cuando tengas datos
DATA_DIR = os.path.join(os.getcwd(), "data_raw")
os.makedirs(DATA_DIR, exist_ok=True)
print("DATA_DIR:", DATA_DIR)
# Out:
# DATA_DIR: c:\Users\knflm\Documents\disney-monomyth-analytics\notebooks\data_raw

# %%
df = pd.DataFrame({
    "movie": ["Snow White", "Pinocchio"],
    "year": [1937, 1940],
    "runtime_min": [83, 87]
})
df.head()
# Out:
#         movie  year  runtime_min
# 0  Snow White  1937           83
# 1   Pinocchio  1940           87
